# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("train.csv")
dataset.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
# To find the dataset balanced or not
plt.figure(figsize=(14,8))
sns.countplot(dataset["department"])
plt.show()
# Out:
# C:\Users\Infanta Princy\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset.corr()
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.005121  0.000437
# no_of_trainings         -0.005121         1.000000 -0.081278
# age                      0.000437        -0.081278  1.000000
# previous_year_rating     0.004533        -0.063126  0.006008
# length_of_service        0.001274        -0.057275  0.657111
# KPIs_met >80%           -0.002501        -0.045576 -0.025592
# awards_won?              0.008420        -0.007628 -0.008169
# avg_training_score      -0.000586         0.042517 -0.048380
# is_promoted              0.001206        -0.024896 -0.017166
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                       0.004533           0.001274      -0.002501
# no_of_trainings                  -0.063126          -0.057275      -0.045576
# age                               0.006008           0.657111      -0.025592
# ...

# %%
# heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(dataset.corr())
plt.scatter(dataset["awards_won?"], dataset["is_promoted"])
plt.show()

# %%
#pip install -U scikit-learn
# preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
dataset
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
x = dataset.drop("department", axis = 1)
x
# Out:
#        employee_id     region         education gender recruitment_channel  \
# 0            65438   region_7  Master's & above      f            sourcing
# 1            65141  region_22        Bachelor's      m               other
# 2             7513  region_19        Bachelor's      m            sourcing
# 3             2542  region_23        Bachelor's      m               other
# 4            48945  region_26        Bachelor's      m               other
# ...            ...        ...               ...    ...                 ...
# 54803         3030  region_14        Bachelor's      m            sourcing
# 54804        74592  region_27  Master's & above      f               other
# 54805        13918   region_1        Bachelor's      m               other
# 54806        13614   region_9               NaN      m            sourcing
# 54807        51526  region_22        Bachelor's      m               other
#
# ...

# %%
y = dataset["department"]
y
# Out:
# 0        Sales & Marketing
# 1               Operations
# 2        Sales & Marketing
# 3        Sales & Marketing
# 4               Technology
#                ...
# 54803           Technology
# 54804           Operations
# 54805            Analytics
# 54806    Sales & Marketing
# 54807                   HR
# Name: department, Length: 54808, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
X_train
# Out:
#        employee_id     region         education gender recruitment_channel  \
# 3113         27996  region_12        Bachelor's      m               other
# 118          38771  region_23        Bachelor's      f               other
# 17005        55699  region_28        Bachelor's      m               other
# 14505        64111   region_7        Bachelor's      m               other
# 31487        27201  region_17        Bachelor's      m               other
# ...            ...        ...               ...    ...                 ...
# 44732        70143  region_22  Master's & above      f            sourcing
# 54343        48082   region_2        Bachelor's      f            sourcing
# 38158        62588  region_11        Bachelor's      f            sourcing
# 860          61087  region_15  Master's & above      m               other
# 15795        59512  region_22        Bachelor's      m            sourcing
#
# ...

# %%
# Normalization
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
from sklearn.neighbors import KNeighborsClassifier
Knn = KNeighborsClassifier(n_neighbors = 5)

# %%
# Q1. Does Older Employees getting more Promotion than Younger Employees?

# %%
# Q2. What is the Probability to get Promoted, If an employeed has won an award?

# %%
# Q3. What is the Average Training Score of those Employees who got Promotion?

# %%
# Q4. What is the Impact of Gender in Promotions?

# %%
# Q5. What is the Probability of Freshers getting Promoted?
